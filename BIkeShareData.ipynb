# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

BikeShareDayFrame=pd.read_csv('bikeShareDay.csv', delimiter=',')
BikeShareHourFrame=pd.read_csv('bikeShareHour.csv', delimiter=',')

# %%
pd.DataFrame.max(BikeShareDayFrame)
# Out:
# instant              731
# dteday        2012-12-31
# season                 4
# yr                     1
# mnth                  12
# holiday                1
# weekday                6
# workingday             1
# weathersit             3
# temp            0.861667
# atemp           0.840896
# hum               0.9725
# windspeed       0.507463
# casual              3410
# registered          6946
# cnt                 8714
# dtype: object

# %%
pd.DataFrame.max(BikeShareHourFrame)
# Out:
# instant            17379
# dteday        2012-12-31
# season                 4
# yr                     1
# mnth                  12
# hr                    23
# holiday                1
# weekday                6
# workingday             1
# weathersit             4
# temp                   1
# atemp                  1
# hum                    1
# windspeed         0.8507
# casual               367
# registered           886
# cnt                  977
# dtype: object

# %%
pd.DataFrame.min(BikeShareDayFrame)
# Out:
# instant                1
# dteday        2011-01-01
# season                 1
# yr                     0
# mnth                   1
# holiday                0
# weekday                0
# workingday             0
# weathersit             1
# temp           0.0591304
# atemp          0.0790696
# hum                    0
# windspeed      0.0223917
# casual                 2
# registered            20
# cnt                   22
# dtype: object

# %%
pd.DataFrame.min(BikeShareHourFrame)
# Out:
# instant                1
# dteday        2011-01-01
# season                 1
# yr                     0
# mnth                   1
# hr                     0
# holiday                0
# weekday                0
# workingday             0
# weathersit             1
# temp                0.02
# atemp                  0
# hum                    0
# windspeed              0
# casual                 0
# registered             0
# cnt                    1
# dtype: object

# %%
pd.DataFrame.mean(BikeShareDayFrame)
# Out:
# instant        366.000000
# season           2.496580
# yr               0.500684
# mnth             6.519836
# holiday          0.028728
# weekday          2.997264
# workingday       0.683995
# weathersit       1.395349
# temp             0.495385
# atemp            0.474354
# hum              0.627894
# windspeed        0.190486
# casual         848.176471
# registered    3656.172367
# cnt           4504.348837
# dtype: float64

# %%
pd.DataFrame.mean(BikeShareHourFrame)
# Out:
# instant       8690.000000
# season           2.501640
# yr               0.502561
# mnth             6.537775
# hr              11.546752
# holiday          0.028770
# weekday          3.003683
# workingday       0.682721
# weathersit       1.425283
# temp             0.496987
# atemp            0.475775
# hum              0.627229
# windspeed        0.190098
# casual          35.676218
# registered     153.786869
# cnt            189.463088
# dtype: float64

# %%
pd.DataFrame.median(BikeShareDayFrame)
# Out:
# instant        366.000000
# season           3.000000
# yr               1.000000
# mnth             7.000000
# holiday          0.000000
# weekday          3.000000
# workingday       1.000000
# weathersit       1.000000
# temp             0.498333
# atemp            0.486733
# hum              0.626667
# windspeed        0.180975
# casual         713.000000
# registered    3662.000000
# cnt           4548.000000
# dtype: float64

# %%
pd.DataFrame.median(BikeShareHourFrame)
# Out:
# instant       8690.0000
# season           3.0000
# yr               1.0000
# mnth             7.0000
# hr              12.0000
# holiday          0.0000
# weekday          3.0000
# workingday       1.0000
# weathersit       1.0000
# temp             0.5000
# atemp            0.4848
# hum              0.6300
# windspeed        0.1940
# casual          17.0000
# registered     115.0000
# cnt            142.0000
# dtype: float64

# %%
plt.figure()
BikeShareDayFrame.hist(figsize=(20, 20))
plt.show()

# %%
plt.figure()
BikeShareHourFrame.hist(figsize=(20, 20))
plt.show()

# %%
BikeShareDayFrame.plot(kind='box', subplots=True, layout=(4,4),sharex=False, sharey=False, figsize=(20,20))
plt.show()

# %%
BikeShareHourFrame.plot(kind='box', subplots=True, layout=(4,4),
                      sharex=False, sharey=False, figsize=(20,20))
plt.show()

# %%
import seaborn as sns
correlations = BikeShareDayFrame.corr()

f, ax = plt.subplots(figsize=(11, 9))

sns.heatmap(correlations, cmap=('PuBu'), center=0, vmin=-1, vmax=1, square=True)

b, t = plt.ylim()
b += 0.5
t -= 0.5
plt.ylim(b, t)
plt.show()

# %%
import seaborn as sns
correlations = BikeShareHourFrame.corr()

f, ax = plt.subplots(figsize=(11, 9))

sns.heatmap(correlations, cmap=('PuBu'), center=0, vmin=-1, vmax=1, square=True)

b, t = plt.ylim()
b += 0.5
t -= 0.5
plt.ylim(b, t)
plt.show()

# %%
plt.scatter(BikeShareDayFrame['RM'], BikeShareDayFrame['MEDV'])
plt.xlabel('Average number of rooms per dwelling')
plt.ylabel('Median value of owner-occupied homes in $1000s')
plt.show()
plt.scatter(BikeShareDayFrame['LSTAT'], BikeShareDayFrame['MEDV'])
plt.xlabel('% lower status of the population')
plt.ylabel('Median value of owner-occupied homes in $1000s')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RM'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-187d4f9838e0> in <module>()
# ----> 1 plt.scatter(BikeShareDayFrame['RM'], BikeShareDayFrame['MEDV'])
#       2 plt.xlabel('Average number of rooms per dwelling')
#       3 plt.ylabel('Median value of owner-occupied homes in $1000s')
#       4 plt.show()
#       5 plt.scatter(BikeShareDayFrame['LSTAT'], BikeShareDayFrame['MEDV'])
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RM'

# %%
plt.scatter( BikeShareHourFrame['RM'], BikeShareHourFrame['MEDV'])
plt.xlabel('Average number of rooms per dwelling')
plt.ylabel('Median value of owner-occupied homes in $1000s')
plt.show()
plt.scatter( BikeShareHourFrame['LSTAT'], BikeShareHourFrame['MEDV'])
plt.xlabel('% lower status of the population')
plt.ylabel('Median value of owner-occupied homes in $1000s')
plt.show()
