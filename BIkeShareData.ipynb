# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

BikeShareDayFrame=pd.read_csv('bikeShareDay.csv', delimiter=',')
BikeShareHourFrame=pd.read_csv('bikeShareHour.csv', delimiter=',')

# %%
pd.DataFrame.max(BikeShareDayFrame)
# Out:
# instant              731
# dteday        2012-12-31
# season                 4
# yr                     1
# mnth                  12
# holiday                1
# weekday                6
# workingday             1
# weathersit             3
# temp            0.861667
# atemp           0.840896
# hum               0.9725
# windspeed       0.507463
# casual              3410
# registered          6946
# cnt                 8714
# dtype: object

# %%
pd.DataFrame.max(BikeShareHourFrame)
# Out:
# instant            17379
# dteday        2012-12-31
# season                 4
# yr                     1
# mnth                  12
# hr                    23
# holiday                1
# weekday                6
# workingday             1
# weathersit             4
# temp                   1
# atemp                  1
# hum                    1
# windspeed         0.8507
# casual               367
# registered           886
# cnt                  977
# dtype: object

# %%
pd.DataFrame.min(BikeShareDayFrame)
# Out:
# instant                1
# dteday        2011-01-01
# season                 1
# yr                     0
# mnth                   1
# holiday                0
# weekday                0
# workingday             0
# weathersit             1
# temp           0.0591304
# atemp          0.0790696
# hum                    0
# windspeed      0.0223917
# casual                 2
# registered            20
# cnt                   22
# dtype: object

# %%
pd.DataFrame.min(BikeShareHourFrame)
# Out:
# instant                1
# dteday        2011-01-01
# season                 1
# yr                     0
# mnth                   1
# hr                     0
# holiday                0
# weekday                0
# workingday             0
# weathersit             1
# temp                0.02
# atemp                  0
# hum                    0
# windspeed              0
# casual                 0
# registered             0
# cnt                    1
# dtype: object

# %%
pd.DataFrame.mean(BikeShareDayFrame)
# Out:
# instant        366.000000
# season           2.496580
# yr               0.500684
# mnth             6.519836
# holiday          0.028728
# weekday          2.997264
# workingday       0.683995
# weathersit       1.395349
# temp             0.495385
# atemp            0.474354
# hum              0.627894
# windspeed        0.190486
# casual         848.176471
# registered    3656.172367
# cnt           4504.348837
# dtype: float64

# %%
pd.DataFrame.mean(BikeShareHourFrame)
# Out:
# instant       8690.000000
# season           2.501640
# yr               0.502561
# mnth             6.537775
# hr              11.546752
# holiday          0.028770
# weekday          3.003683
# workingday       0.682721
# weathersit       1.425283
# temp             0.496987
# atemp            0.475775
# hum              0.627229
# windspeed        0.190098
# casual          35.676218
# registered     153.786869
# cnt            189.463088
# dtype: float64

# %%
pd.DataFrame.median(BikeShareDayFrame)
# Out:
# instant        366.000000
# season           3.000000
# yr               1.000000
# mnth             7.000000
# holiday          0.000000
# weekday          3.000000
# workingday       1.000000
# weathersit       1.000000
# temp             0.498333
# atemp            0.486733
# hum              0.626667
# windspeed        0.180975
# casual         713.000000
# registered    3662.000000
# cnt           4548.000000
# dtype: float64

# %%
pd.DataFrame.median(BikeShareHourFrame)
# Out:
# instant       8690.0000
# season           3.0000
# yr               1.0000
# mnth             7.0000
# hr              12.0000
# holiday          0.0000
# weekday          3.0000
# workingday       1.0000
# weathersit       1.0000
# temp             0.5000
# atemp            0.4848
# hum              0.6300
# windspeed        0.1940
# casual          17.0000
# registered     115.0000
# cnt            142.0000
# dtype: float64

# %%
plt.figure()
BikeShareDayFrame.hist(figsize=(20, 20))
plt.show()

# %%
plt.figure()
BikeShareHourFrame.hist(figsize=(20, 20))
plt.show()

# %%
BikeShareDayFrame.plot(kind='box', subplots=True, layout=(4.4),
                      sharex=False, sharey=False, figsize=(20,20))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-139472dca3af> in <module>()
#       1 BikeShareDayFrame.plot(kind='box', subplots=True, layout=(4.4),
# ----> 2                       sharex=False, sharey=False, figsize=(20,20))
#       3 plt.show()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2942                           sort_columns=sort_columns, **kwds)
#    2943     __call__.__doc__ = plot_frame.__doc__
#    2944
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1971                  yerr=yerr, xerr=xerr,
#    1972                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1973                  **kwds)
#    1974
#    1975
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1799         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1800
# -> 1801     plot_obj.generate()
#    1802     plot_obj.draw()
#    1803     return plot_obj.result
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/plotting/_core.py in generate(self)
#     248         self._args_adjust()
#     249         self._compute_plot_data()
# --> 250         self._setup_subplots()
#     251         self._make_plot()
#     252         self._add_table()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/plotting/_core.py in _setup_subplots(self)
#     299                                   figsize=self.figsize, ax=self.ax,
#     300                                   layout=self.layout,
# --> 301                                   layout_type=self._layout_type)
#     302         else:
#     303             if self.ax is None:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/plotting/_tools.py in _subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     227             fig.clear()
#     228
# --> 229     nrows, ncols = _get_layout(naxes, layout=layout, layout_type=layout_type)
#     230     nplots = nrows * ncols
#     231
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/plotting/_tools.py in _get_layout(nplots, layout, layout_type)
#      69     if layout is not None:
#      70         if not isinstance(layout, (tuple, list)) or len(layout) != 2:
# ---> 71             raise ValueError('Layout must be a tuple of (rows, columns)')
#      72
#      73         nrows, ncols = layout
#
# ValueError: Layout must be a tuple of (rows, columns)

# %%
BikeShareHourFrame.plot(kind='box', subplots=True, layout=(4.4),
                      sharex=False, sharey=False, figsize=(20,20))
plt.show()

# %%
import seaborn as sns
correlations = BikeShareDayFrame.corr()

f, ax = plt.subplots(figsize=(11, 9))

sns.heatmap(correlations, cmap=('PuBu'), center=0, vmin=-1, vmax=1, square=True)

b, t = plt.ylim()
b += 0.5
t -= 0.5
plt.ylim(b, t)
plt.show()

# %%
import seaborn as sns
correlations = BikeShareHourFrame.corr()

f, ax = plt.subplots(figsize=(11, 9))

sns.heatmap(correlations, cmap=('PuBu'), center=0, vmin=-1, vmax=1, square=True)

b, t = plt.ylim()
b += 0.5
t -= 0.5
plt.ylim(b, t)
plt.show()

# %%
plt.scatter(BikeShareDayFrame['RM'], BikeShareDayFrame['MEDV'])
plt.xlabel('Average number of rooms per dwelling')
plt.ylabel('Median value of owner-occupied homes in $1000s')
plt.show()
plt.scatter(BikeShareDayFrame['LSTAT'], BikeShareDayFrame['MEDV'])
plt.xlabel('% lower status of the population')
plt.ylabel('Median value of owner-occupied homes in $1000s')
plt.show()

# %%
plt.scatter( BikeShareHourFrame['RM'], BikeShareHourFrame['MEDV'])
plt.xlabel('Average number of rooms per dwelling')
plt.ylabel('Median value of owner-occupied homes in $1000s')
plt.show()
plt.scatter( BikeShareHourFrame['LSTAT'], BikeShareHourFrame['MEDV'])
plt.xlabel('% lower status of the population')
plt.ylabel('Median value of owner-occupied homes in $1000s')
plt.show()
